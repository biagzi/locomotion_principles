# %%
# %config Completer.use_jedi = False
import os
import pandas as pd
import matplotlib.pyplot as  plt
import seaborn as sns
import numpy as np
import sys

COMPUTER_NAME = '/home/renata'

sys.path.append('{0}/locomotion_principles/'.format(COMPUTER_NAME))
from transferenceSelectedShapes.TransferenceAnalysis import transference_dict

encode = 'latin1'
print('Using python {0}'.format(sys.version_info[0])) #use python 3
sns.set(font_scale=2)  # good size
sns.set_style("white")
# Out:
# /home/renata/anaconda2/envs/python3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Config option `use_jedi` not recognized by `IPCompleter`.
#   """Entry point for launching an IPython kernel.
# Using python 3

# %%
SELECT_ROBOT = 'BEST'
plot_df = transference_dict(SELECT_ROBOT,encode)

# %%
sns.set(font_scale=1.5)  # good size
sns.set_style("white")
sns.set_style("ticks")
c = sns.catplot(x="Env", y="AchievedFit", hue="OriginalEnv",
                capsize=.15, height=8, aspect=1.25
                ,kind="point", data=plot_df,
                hue_order = ['AQUA','MARS','EARTH'],order = ['AQUA','MARS','EARTH'],
                palette = sns.color_palette()
                ,legend_out = False
                ,join = True)
plt.savefig('ActivedFitinTransference.png')
